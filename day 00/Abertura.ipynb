# %% [markdown]
# # MBA em Inteligência Artificial e Ciência de Dados

# %% [markdown]
# ## Python e Ciência de Dados I

# %% [markdown]
# 👉 Manipulação de dados com pandas e numpy

# %% [markdown]
# ### Sumário

# %% [markdown]
# <ul>
#     <li>Instrutor</li>
#     <li>Principais Aspectos do Programa</li>
#     <ul>
#         <li>Objetivo Geral</li>
#         <li>Ementa</li>
#         <li>Cronograma</li>
#         <li>Ferramentas</li>
#         <li>Avaliação de Aprendizagem</li>
#         <li>Bibliografia</li>
#     </ul>
# </ul>

# %% [markdown]
# ### Instrutor

# %% [markdown]
# <table align='center'>
#     <tr align='center'>
#         <td align='center'>Hélio Bomfim de Macêdo Filho</td>
#     </tr>
#     <tr align='center'>
#         <td align='center'><img src='figs/Helio.png' width=150></td>
#     </tr>
#     <tr align='center'>
#         <td align='center'>DSc., Eng. de Sistemas e Computação, UFRJ<br />Especialista em Políticas Públicas e Gestão Governamental<br />Coordenador-Geral de Acompanhamento de Programas<br/>Ministério do Desenvolvimento e Assistência Social, Família e Combate à Fome</td>
#     </tr>
# </table>

# %% [markdown]
# # Principais Aspectos do Programa

# %% [markdown]
# ## Objetivo Geral

# %% [markdown]
# Capacitar os participantes com conhecimentos essenciais de manipulação de dados nas principais bibliotecas do Python para uso em Inteligência Artificial e Ciência de Dados

# %% [markdown]
# <table align='center'>
#     <tr>
#         <th>Data</td><td>14, 16 e 28 de abril de 2026</td>
#     </tr>
#     <tr>
#         <th>Horário</td><td>19h às 22h15m, com intervalo de 15 min</td>
#     </tr>
#     <tr>
#         <th>Carga Horária</td><td>24 horas (9 horas síncronas e 15 horas assíncronas)</td>
#     </tr>
#     <tr>
#         <th>Nível de Formação</td><td>MBA em Inteligência Artificial e Ciência de Dados</td>
#     </tr>
#     <tr>
#         <th>Site</td><td>https://online.idp.edu.br/curso/mba-em-inteligencia-artificial-e-ciencia-de-dados/</td>
#     </tr>
# </table>

# %% [markdown]
# ## Ementa

# %% [markdown]
# <ol>
#     <li>Plataformas para desenvolvimento em Python;</li>
#     <li>Introdução a manipulação de dados em alto desempenho com numpy;</li>
#     <li>Introdução a manipulação de dados em alto desempenho com pandas;</li>
#     <li>Limpeza e Preparação dos Dados com Pandas; e</li>
#     <li>Tratamento e Agregação dos Dados com Pandas.</li>
# </ol>

# %% [markdown]
# ## Cronograma

# %% [markdown]
# <table align='center' width='100%'>
#     <tr align='center'>
#         <th align='center'>14 de abril de 2026</th>
#         <th align='center'>26 de abril de 2026</th>
#         <th align='center'>28 de abril de 2026</th>
#     </tr>
#     <tr align='center'>
#         <td align='center'>Plataformas para desenvolvimento em Python<br />Introdução a manipulação de dados em alto desempenho com numpy e pandas (Series)</td>
#         <td align='center'>Introdução a análise de dados em alto desempenho com pandas (DataFrame)<br />Limpeza e Preparação dos Dados</td>
#         <td align='center'>Tratamento e Agregação dos Dados</td>
#     </tr>
# </table>

# %% [markdown]
# ## Ferramentas

# %% [markdown]
# ### Inteligência Artificial e Ciência de Dados

# %% [markdown]
# <table align='center' width='100%'>
#     <tr align='center'>
#         <td align='center'><img src='figs/logo-jupyter.png' width=50></td>
#         <td align='center'><img src='figs/logo-python.png' width=100></td>
#         <td align='center'><img src='figs/logo-numpy.png' width=100></td>
#         <td align='center'><img src='figs/logo-pandas.png' width=100></td>
#     </tr>
#     <tr align='center'>
#         <td align='center'>Jupyter Lab</td>
#         <td align='center'>Python</td>
#         <td align='center'>NumPy</td>
#         <td align='center'>Pandas</td>
# </table>

# %% [markdown]
# ### Apoio

# %% [markdown]
# <table align='center' width='100%'>
#     <tr align='center'>
#         <td align='center'><img src='figs/logo-zoom.svg' width=100></td>
#         <td align='center'><img src='https://www.idp.edu.br/wp-content/themes/idp_principal_2020/img/logo-idp-whatsapp.png' width=100></td>
#     </tr>
#     <tr align='center'>
#         <td align='center'>Zoom</td>
#         <td align='center'>IDP</td>
#     </tr>
# </table>

# %% [markdown]
# ## Avaliação da Aprendizagem

# %% [markdown]
# A avaliação da aprendizagem será composta por caso(s) de uso(s) no formato de caderno de exercícios.

# %% [markdown]
# ## Bibliografia

# %% [markdown]
# ### Bibliografia Básica

# %% [markdown]
# McKinney W. Python Para Análise de Dados: Tratamento de Dados com Pandas, NumPy & Jupyter, Terceira Edição. 2023. O'Reilly Media, Inc.

# %% [markdown]
# ### Bibliografia Complementar

# %% [markdown]
# John V. Guttag. Introduction to Computation and Programming Using Python: With Application to Computational Modeling and Understanding Data. 2021. The MIT Press

# %% [markdown]
# <font size=7><center><code>Bom curso a todos</code></center></font>
