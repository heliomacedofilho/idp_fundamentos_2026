# %% [markdown]
# # Pandas 🐼

# %% [markdown]
# ## Sumário da Aula

# %% [markdown]
# <ul>
#     <li>Pandas 🐼</li>
#     <ul>
#         <li>Aspectos do Pandas 🐼</li>
#         <li>Series 🎞️</li>
#     </ul>
# </ul>

# %% [markdown]
# ## Pandas 🐼

# %% [markdown]
# ### Biblioteca Principal 📚: pandas

# %% [markdown]
# <img src="https://pandas.pydata.org/docs/_static/pandas.svg" width="100" style="float: right;">

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.4-cp313-cp313-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/heliomacedofilho/.pyenv/versions/3.13.4/envs/idp_fundamentos_2026/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/heliomacedofilho/.pyenv/versions/3.13.4/envs/idp_fundamentos_2026/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.2-cp313-cp313-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 55.5 MB/s  0:00:00
# Downloading numpy-2.4.4-cp313-cp313-macosx_14_0_arm64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 56.5 MB/s  0:00:00
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]━━━━ 1/2 [pandas]
# Successfully installed numpy-2.4.4 pandas-3.0.2

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp313-cp313-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/heliomacedofilho/.pyenv/versions/3.13.4/envs/idp_fundamentos_2026/lib/python3.13/site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/heliomacedofilho/.pyenv/versions/3.13.4/envs/idp_fundamentos_2026/lib/python3.13/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/heliomacedofilho/.pyenv/versions/3.13.4/envs/idp_fundamentos_2026/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/heliomacedofilho/.pyenv/versions/3.13.4/envs/idp_fundamentos_2026/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.8-cp313-cp313-macosx_11_0_arm64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp313-cp313-macosx_10_13_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 48.9 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp313-cp313-macosx_11_0_arm64.whl (64 kB)
# Downloading pillow-12.2.0-cp313-cp313-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 60.3 MB/s  0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib] 6/7 [matplotlib]ow]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.2.0 pyparsing-3.3.2

# %%
import pandas as pd

# %%
df = pd.DataFrame({"pop_estimada": [27000, 32000], "estado": ['SP', 'RJ']}).set_index('estado')

# %%
df.plot(kind='bar');

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import pandas as pd

# %%
pd.read_excel('tabela6579.xlsx', header=3).rename(columns={'Unnamed: 0': 'estado', '2025': 'pop.estimada (2025)'}).iloc[:-1].set_index('estado').plot(kind='bar')
# Out:
# <Axes: xlabel='estado'>

# %% [markdown]
# ### Aspectos do Pandas 🐼

# %% [markdown]
# <ul>
#     <li>Análise de Dados 🕵🏽 🎲 em Alto Desempenho 🚀 🧞‍♂️</li>
#     <li>Frequentemente utilizado com bibliotecas:
#         <ul>
#             <li>de computação numérica, e.g. NumPy, SciPy;</li>
#             <li>analíticas, e.g. como statsmodels e scikit-learn</li>
#             <li>de visualização de dados, e.g. matplotlib e seaborn.</li>
#         </ul>
#     </li>
#     <li>Adota o estilo idiomático de Computação Vetorizada 🧮 do NumPy, especialmente:
#         <ul>
#             <li>função baseada em vetores (<i>arrays</i>)</li>
#             <li>preferência por processamento de dados sem laços <i>for</i></li>
#         </ul>
#     </li>
#     <li>No entanto, há uma diferença significativa:
#         <ul>
#             <li>Pandas é desenhado para trabalhar com dados tabulares e heterogêneos; e</li>
#             <li>NumPy é desenhado para trabalhar com dados numéricos homogêneos.</li>
#         </ul>
#     </li>
#     <li>É maduro, aplicável em um vasto cenário de casos de usos reais e tem uma comunidade com mais de 2500 colaboradores</li>
# </ul>

# %% [markdown]
# <img src="https://www.w3resource.com/w3r_images/pandas-series-image.svg" style="margin-left: auto; margin-right: auto;">

# %% [markdown]
# 👉 Referência: <a href='https://pandas.pydata.org/'>pandas.pydata.org</a>

# %% [markdown]
# 👉 Pandas <a href='https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf'>cheat sheet</a>

# %% [markdown]
# ### Series 🎞️

# %% [markdown]
# <ul>
#     <li>Objeto de <b>uma</b> dimensão (semelhante ao vetor - <i>array</i>) e equivalente ao <b>1D ndarray</b> do NumPy</li>
#     <ul>
#         <li>contém uma sequência de valores; e</li>
#         <li>um vetor (<i>array</i>) de rótulos chamado de índice (<i>index</i>)</li>
#     </ul>
# </ul>

# %% [markdown]
# 👉 Referência: <a href='https://pandas.pydata.org/docs/reference/api/pandas.Series.html'>pandas.Series</a>

# %% [markdown]
# <pre>Você pode criar uma Series com a sequência de valores -- <u>sem</u> o vetor (<i>array</i>) de índices</pre>

# %%
# Exemplo: Uma série com o PIB de países
# (Pib per capta - anual em dólares)

pd.Series([6797, 63123, 8476])
# Out:
# 0     6797
# 1    63123
# 2     8476
# dtype: int64

# %% [markdown]
# <pre>... ou com a sequência de valores -- e <u>com</u> o vetor (<i>array</i>) de índices -- com listas</pre>

# %%
# Quero inserir o indice para as linhas 
# (para saber qual país possui qual PIB_pc)
pd.Series(data=[6797, 63123, 8476], 
          index=['Brasil', 'EUA', 'Argentina'])
# Out:
# Brasil        6797
# EUA          63123
# Argentina     8476
# dtype: int64

# %% [markdown]
# <pre>... ou com a sequência de valores -- e <u>com</u> o vetor (<i>array</i>) de índices -- como dicionário...</pre>

# %%
pd.Series({'Brasil': 6797, 'EUA': 63123, 'Argentina': 8476})
# Out:
# Brasil        6797
# EUA          63123
# Argentina     8476
# dtype: int64

# %% [markdown]
# <pre>... e ainda especificar separadamente o vetor (<i>array</i>) de índices</pre>

# %% [markdown]
# 👉 dica: o vetor (<i>array</i>) de índices especificado separadamente pode ser diferente dos índices do dicionário !

# %%
pd.Series({'Brasil': 6797, 'EUA': 63123, 'Argentina': 8476}, 
          index=['Brasil', 'EUA', 'Canada', 'Argentina'])
# Out:
# Brasil        6797.0
# EUA          63123.0
# Canada           NaN
# Argentina     8476.0
# dtype: float64

# %% [markdown]
# <pre>Você pode utilizar o índice para acessar o valor</pre>

# %% [markdown]
# 👉  dica: usar em contextos onde um dicionário seria utilizado

# %%
pibpc = pd.Series({'Brasil': 6797, 'EUA': 63123, 'Argentina': 8476})

# %%
pibpc['Brasil']
# Out:
# np.int64(6797)

# %%
pibpc['Argentina'] = 8000
pibpc['Argentina']
# Out:
# np.int64(8000)

# %%
pibpc[['Argentina', 'EUA']]
# Out:
# Argentina     8000
# EUA          63123
# dtype: int64

# %% [markdown]
# <pre>Você pode verificar se um elemento pertence ao <b>índice</b> de uma Serie com a palavra reservada <b>in</b></pre>

# %%
'Brasil' in pibpc
# Out:
# True

# %%
'Uruguai' in pibpc
# Out:
# False

# %% [markdown]
# <pre>Você pode utilizar as operações do NumPy em uma Series</pre>

# %% [markdown]
# (exemplo 1) filtro com um vetor de booleanos

# %%
pibpc[pibpc > 7000]
# Out:
# EUA          63123
# Argentina     8000
# dtype: int64

# %% [markdown]
# (exemplo 2) operacão com escalar

# %%
# pib pc em milhares
pibpc/1000
# Out:
# Brasil        6.797
# EUA          63.123
# Argentina     8.000
# dtype: float64

# %% [markdown]
# (exemplo 3) função matemática

# %%
pibpc.sum()
# Out:
# np.int64(77920)

# %% [markdown]
# <pre>Você pode verificar quais valores são ausentes/indisponíveis (<i>NA</i>) e quais não são em uma Series</pre>

# %%
s2 = pd.Series({"Ohio": 35000, "Texas": 71000, 
                "Oregon": 16000, "Utah": 5000}, 
               index=["California", "Ohio", "Oregon", "Texas"])
s2
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isna(s2)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notna(s2)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
s2.isna()
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %% [markdown]
# <pre>Você pode automaticamente alinhar os valores correspondentes ao mesmo índice por meio da operação de soma</pre>

# %%
s3 = pd.Series({"Ohio": 35000, "Texas": 71000, "Oregon": 16000, 
                "Utah": 5000})

# %%
s2
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
s3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
s2 + s3
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %% [markdown]
# <pre>Você pode atribuir nomes aos índices, à Serie e aos elementos do índice</pre>

# %%
s2
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
s2.name = 'population'
s2.index = ['California', 'Ohio', 'Oregon', 'Texas']
s2.index.name = 'state'
s2
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %% [markdown]
# <pre>Você pode remover uma entrada da Serie</pre>

# %%
s2 = s2.drop('California')
s2
# Out:
# state
# Ohio      35000.0
# Oregon    16000.0
# Texas     71000.0
# Name: population, dtype: float64
